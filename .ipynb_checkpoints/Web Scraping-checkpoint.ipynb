# %%
import requests
import urllib3.request
import time
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# # Finding Links

# %%
links_2019 = []

# %%
url = 'http://www.ufcstats.com/statistics/events/completed'
req = requests.get(url, headers)
soup = BeautifulSoup(req.content, 'html.parser')
links_arr = soup.find_all("a" , class_="b-link b-link_style_black")

# %%
for i in links_arr:
    links_2019.append(i['href'].encode('UTF8'))

# %%
url = 'http://www.ufcstats.com/statistics/events/completed?page=2'
req = requests.get(url, headers)
soup = BeautifulSoup(req.content, 'html.parser')
links_arr = soup.find_all("a" , class_="b-link b-link_style_black")

# %%
for i in links_arr:
    links_2019.append(i['href'].encode('UTF8'))

# %%
# Removing Non 2019 Fight Cards
links_2019 = links_2019[0:-7]

# %%
#Showing some links for example
links_2019[0:5]
# Out:
# ['http://www.ufcstats.com/event-details/74fefd43f073cd2f',
#  'http://www.ufcstats.com/event-details/4565d435005319c0',
#  'http://www.ufcstats.com/event-details/b09890ba7ce1d1e2',
#  'http://www.ufcstats.com/event-details/81ca2c245b19b3c5',
#  'http://www.ufcstats.com/event-details/8d5daf67983b65ba']

# %%
def UFC_to_df(links):
    WL = []
    Fighters = []
    Opponent = []

    Strikes = []
    TakeDowns = []
    Submission = []
    Passes = []
    Weight = []
    Method = []
    MethodDescription = []
    Round = []
    Time = []
    
    
    headers = requests.utils.default_headers()
    headers.update({ 'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'})
    temp_list = []
    for link in links:
        url = link
        req = requests.get(url, headers)
        soup = BeautifulSoup(req.content, 'html.parser')
        total = soup.find_all("p" , class_="b-fight-details__table-text")
        temp_list = []
        for i in total:
    
            item = i.text.encode('UTF8') ## Taking Text and converting from unicode to string
            temp_list.append(" ".join(item.split()))
        
        count = 0
        for index, i in enumerate(temp_list):
            if count < 2:
                if i == 'win':
                    WL.append('Win')
                    WL.append('Loss')
                    count += 2
                else:
                    WL.append('Draw')
                    count += 1

            elif count < 3:
                Fighters.append(i)
                Opponent.append(temp_list[index + 1])

                count += 1
            elif count < 4:
                Fighters.append(i)
                Opponent.append(temp_list[index - 1])
                count += 1
            elif count < 6:
                Strikes.append(i)
                count += 1
            elif count < 8:
                TakeDowns.append(i)
                count += 1
            elif count < 10:
                Submission.append(i)
                count += 1
            elif count < 12:
                Passes.append(i)
                count += 1
            elif count < 13:
                Weight.append(i)
                Weight.append(i)
                count += 1
            elif count < 14:
                Method.append(i)
                Method.append(i)
                count += 1
            elif count < 15:
                MethodDescription.append(i)
                MethodDescription.append(i)

                count += 1
            elif count < 16:
                Round.append(i)
                Round.append(i)
                count +=1
            elif count < 17:
                Time.append(i)
                Time.append(i)
                count = 0

    results = pd.DataFrame({'WL': WL, 
                            'Fighter': Fighters, 
                            'Opponent' : Opponent,
                            'Strikes': Strikes, 
                            'Take_Downs' : TakeDowns,
                            'Sub_Attempts' : Submission,
                            'Passes' : Passes,
                            'Weight' : Weight,
                            'Method' : Method,'Finish_Description' : MethodDescription,
                            'Round' : Round,
                            'Time' : Time
                   
                  })
    return (results)

# %% [markdown]
# ### Only use if you need to scrape more data

# %%
# df = UFC_to_df(links_2019)
# df.to_csv('2019 Fights.csv')

# %%
df = pd.read_csv('2019 Fights.csv')

# %%
df
# Out:
#       Unnamed: 0                Fighter  Finish_Description  Method  \
# 0              0         Chan Sung Jung             Punches  KO/TKO
# 1              1          Frankie Edgar             Punches  KO/TKO
# 2              2        Volkan Oezdemir                 NaN   S-DEC
# 18    4:17   Win            Flyweight
# 19    4:17  Loss            Flyweight
# 20    5:00   Win         Bantamweight
# 21    5:00  Loss         Bantamweight
# 22    3:43   Win  Women's Strawweight
# 23    3:43  Loss  Women's Strawweight
# 24    5:00   Win         Bantamweight
# 25    5:00  Loss         Bantamweight
# 26    4:10   Win         Welterweight
# 27    4:10  Loss         Welterweight
# 28    5:00   Win        Featherweight
# 29    5:00  Loss        Featherweight
# ...    ...   ...                  ...
# 1002  2:28   Win         Bantamweight
# 1003  2:28  Loss         Bantamweight
# 1004  5:00   Win            Flyweight
# 1005  5:00  Loss            Flyweight
# 1006  0:32   Win            Flyweight
# 1007  0:32  Loss            Flyweight
# 1008  2:28   Win          Heavyweight
# 1009  2:28  Loss          Heavyweight
# 1010  4:59   Win          Lightweight
# 1011  4:59  Loss          Lightweight
# 1012  5:00   Win            Flyweight
# 1013  5:00  Loss            Flyweight
# 1014  1:50   Win    Women's Flyweight
# 1015  1:50  Loss    Women's Flyweight
# 1016  3:21   Win    Light Heavyweight
# 1017  3:21  Loss    Light Heavyweight
# 1018  3:43   Win          Lightweight
# 1019  3:43  Loss          Lightweight
# 1020  5:00   Win    Women's Flyweight
# 1021  5:00  Loss    Women's Flyweight
# 1022  3:56   Win    Light Heavyweight
# 1023  3:56  Loss    Light Heavyweight
# 1024  3:31   Win         Bantamweight
# 1025  3:31  Loss         Bantamweight
# 1026  5:00   Win          Lightweight
# 1027  5:00  Loss          Lightweight
# 1028  5:00   Win         Welterweight
# 1029  5:00  Loss         Welterweight
# 1030  2:25   Win         Welterweight
# 1031  2:25  Loss         Welterweight
#
# [1032 rows x 13 columns]

# %% [markdown]
# ### What do I really want to look at?

# %% [markdown]
# - Number of Minutes spent in the Octagon
# - Most efficient fighter
# - Finish Breakdown, then by round

# %% [markdown]
# ## Finish Breakdowns

# %%
df.groupby('Finish_Description').count().Method // 2
# Out:
# Finish_Description
# Anaconda Choke         4
# Arm Triangle           8
# Armbar                 9
# Elbow                  2
# Elbows                 9
# Flying Knee            3
# Guillotine Choke      10
# Heel Hook              1
# Kick                  16
# Kimura                 1
# Knee                   5
# Knees                  1
# Neck Crank             1
# Other                  1
# Other - Choke          3
# Peruvian Necktie       1
# Punch                 68
# Punches               40
# Rear Naked Choke      35
# Slam                   1
# Spinning Back Fist     2
# Spinning Back Kick     2
# Triangle Choke         7
# Name: Method, dtype: int64

# %%
df.groupby(['Finish_Description','Round']).count().Method //2
# Out:
# Finish_Description  Round
# Anaconda Choke      2         4
# Arm Triangle        1         2
#                     2         3
#                     3         2
#                     4         1
# Armbar              1         4
#                     2         3
#                     3         2
# Elbow               2         1
#                     3         1
# Elbows              1         4
#                     2         3
#                     3         2
# Flying Knee         1         3
# Guillotine Choke    1         6
#                     2         1
#                     3         3
# Heel Hook           3         1
# Kick                1         7
#                     2         4
#                     3         5
# Kimura              1         1
# Knee                1         2
#                     3         3
# Knees               1         1
# Neck Crank          1         1
# Other               1         1
# Other - Choke       1         1
#                     2         2
# Peruvian Necktie    1         1
# Punch               1        44
#                     2        12
#                     3        10
#                     5         2
# Punches             1        19
#                     2        16
#                     3         4
#                     4         1
# Rear Naked Choke    1        14
#                     2        14
#                     3         6
#                     4         1
# Slam                2         1
# Spinning Back Fist  1         1
#                     2         1
# Spinning Back Kick  1         2
# Triangle Choke      1         4
#                     2         2
#                     3         1
# Name: Method, dtype: int64
